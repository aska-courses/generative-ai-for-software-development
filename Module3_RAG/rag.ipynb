# %%
from ingest import build_and_save_vectorstore
from app import run_app

# %%
build_and_save_vectorstore()
# Out:
# WARNING:langchain_text_splitters.base:Created a chunk of size 1088, which is longer than the specified 1000
# Loaded 31 documents from knowledge-base
# Total number of chunks: 123
# Document types: {'employees', 'company', 'products', 'contracts'}
# There are 123 vectors with 1,536 dimensions in the vector store
# Vector store saved to directory: vector_db

# %%
run_app()
# Out:
# Rerunning server... use `close()` to stop if you need to change `launch()` parameters.
# ----
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://baf14f9517b6542ed1.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://baf14f9517b6542ed1.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
